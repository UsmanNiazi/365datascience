# %%
George
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-669897961384> in <module>()
# ----> 1 George
#
# NameError: name 'George' is not defined

# %%
'George'
# Out:
# 'George'

# %%
"George"
# Out:
# 'George'

# %%
print ('George')
# Out:
# George

# %%
print ("George")
# Out:
# George

# %%
x4 = "George"

# %%
x4
# Out:
# 'George'

# %%
y = 10
print (y + "Dollars")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-798a37ed70c4> in <module>()
#       1 y = 10
# ----> 2 print (y + "Dollars")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
y = 10
print (str(y) + " Dollars")
# Out:
# 10 Dollars

# %%
'I'm fine'
# Out:
#   File "<ipython-input-10-4b03f9290adb>", line 1
#     'I'm fine'
#        ^
# SyntaxError: invalid syntax

# %%
"I'm fine"
# Out:
# "I'm fine"

# %%
'I\'m fine'
# Out:
# "I'm fine"

# %%
'Press "Enter"'
# Out:
# 'Press "Enter"'

# %%
'Red' 'car'
# Out:
# 'Redcar'

# %%
'Red ' 'car'
# Out:
# 'Red car'

# %%
'Red ' + 'car'
# Out:
# 'Red car'

# %%
print ('Red ' + 'car')
# Out:
# Red car

# %%
print ('Red', 'car')
# Out:
# Red car

# %%
print (3,5)
# Out:
# 3 5

# %%
3, 5, 6.9, 7.0, 'car'
# Out:
# (3, 5, 6.9, 7.0, 'car')
